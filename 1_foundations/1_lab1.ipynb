# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday, what time is it now?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step.
#
# ---
#
# ### Problem restatement:
# > Two hours ago, the time was *as long after* 1:00 PM as it was *before* 1:00 AM **yesterday**.
#
# We want to find **the current time**.
#
# ---
#
# ### Step 1: Define variables and interpret the problem
#
# - Let the current time be \( T \) (in hours and minutes, or decimal hours).
# - Two hours ago, the time was \( T - 2 \).
#
# The problem refers to two reference points on the clock:
# - 1:00 PM (13:00) **today**.
# - 1:00 AM (1:00) **yesterday**.
#
# "Two hours ago, it was as long after 1:00 PM as it was before 1:00 AM yesterday."
#
# ---
#
# ### Step 2: Understand "as long after" and "as long before"
#
# - "As long after 1:00 PM" means the difference between \( T-2 \) and 13:00, specifically:
#   \[
#   \text{time after 1:00 PM} = (T - 2) - 13:00
#   \]
#
# - "As long before 1:00 AM yesterday" means the difference between 1:00 AM **yesterday** and \( T-2 \), specifically:
#   \[
#   \text{time before 1:00 AM yesterday} = 1:00\ \text{AM yesterday} - (T - 2)
#   \]
#
# Since \( T - 2 \) is after 1:00 PM today, the "before 1:00 AM yesterday" time interval refers to the **duration from \( T-2 \) backwards in time to 1:00 AM of the previous day**.
#
# ---
#
# ### Step 3: Set a timeline reference
#
# To compare times consistently, it's best to convert all times into a continuous time measurement, e.g., hours elapsed since a reference point.
#
# Let’s use **midnight at the start of today** (00:00 AM today) as reference:
#
# - 1:00 PM today is: \( 13 \) hours after midnight.
# - 1:00 AM yesterday is: \( 1 \) hour after midnight **yesterday**.
#
# Since yesterday is 24 hours before today, 1:00 AM yesterday is \( 1 - 24 = -23 \) hours relative to midnight today.
#
# ---
#
# ### Step 4: Express everything as hours relative to midnight today
#
# Let current time \( T \) be hours after midnight today. So \( T \) is between 0 (midnight) and 24 (next midnight).
#
# Two hours ago is \( T - 2 \).
#
# We write the condition:
#
# \[
# \text{(after 1:00 PM)} = \text{(before 1:00 AM yesterday)}
# \]
#
# In hours,
#
# \[
# (T - 2) - 13 = (-23) - (T - 2)
# \]
#
# ---
#
# ### Step 5: Solve the equation
#
# \[
# (T - 2) - 13 = -23 - (T - 2)
# \]
#
# Simplify left side:
#
# \[
# T - 15 = -23 - T + 2
# \]
#
# \[
# T - 15 = -21 - T
# \]
#
# Bring all terms to one side:
#
# \[
# T + T = -21 + 15
# \]
#
# \[
# 2T = -6
# \]
#
# \[
# T = -3
# \]
#
# A negative time \( T = -3 \) means 3 hours **before** midnight today, i.e., 21:00 (9:00 PM) the day before. The negative outcome suggests we must reconsider what \( T \) means and whether \( T \) is on the same day or not.
#
# ---
#
# ### Step 6: Check the time domain assumptions
#
# - Current time \( T \) cannot be negative.
# - This means the answer is **before midnight today** or on the previous day.
# - Since \( T = -3 \) hours relative to midnight today, it corresponds to 9:00 PM yesterday.
#
# ---
#
# ### Step 7: Interpret \( T = -3 \) (9:00 PM yesterday)
#
# - Current time \( T = -3 \) = 9:00 PM yesterday
# - Two hours ago \( T - 2 = -5 \) = 7:00 PM yesterday
#
# Check if condition holds:
#
# - After 1:00 PM (13:00) today:
#
#   \( (T - 2) - 13 = -5 - 13 = -18 \) hours
#
#   Negative means that \( T-2 \) is **before** 1:00 PM today, so no.
#
# Try interpreting "after 1:00 PM" and "before 1:00 AM" differently.
#
# ---
#
# ### Step 8: Consider the problem from a 12-hour clock perspective
#
# Maybe the problem is about the **clock time only**, not absolute times.
#
# ---
#
# ### Step 9: Interpret the statement differently
#
# "Two hours ago, it was as long after 1 o’clock in the afternoon as it was before 1 o’clock in the morning yesterday."
#
# Translate literally:
#
# - Let \( t_0 \) = time two hours ago.
#
# - Then,
#
# \[
# t_0 - 13:00 = 1:00\ \text{AM yesterday} - t_0
# \]
#
# But 1:00 AM yesterday is 24 hours **before** 1:00 AM today, so the difference \( 1:00 AM yesterday - t_0 \) expresses a time interval.
#
# If:
#
# \[
# (t_0 - 13:00) = (1:00 AM yesterday - t_0)
# \]
#
# then adding \( t_0 + t_0 \) to both sides:
#
# \[
# 2t_0 = 13:00 + 1:00 AM yesterday
# \]
#
# ---
#
# ### Step 10: Representing times as minutes from a base point
#
# Represent both times as minutes from a reference:
#
# - Let the reference be midnight today.
#
# - \( t_0 \) is some time between 0 and 24 hours.
#
# 1:00 AM yesterday is -23 hours from midnight today, or
#
# \[
# -23 \times 60 = -1380 \text{ minutes}
# \]
#
# 13:00 today is
#
# \[
# 13 \times 60 = 780 \text{ minutes}
# \]
#
# The equation:
#
# \[
# 2t_0 = 780 + (-1380) = -600 \text{ minutes}
# \]
#
# \[
# t_0 = -300 \text{ minutes} = -5 \text{ hours}
# \]
#
# So two hours ago was 5 hours before midnight today, which is 7:00 PM yesterday.
#
# Thus the current time \( T = t_0 + 2 \) is
#
# \[
# -5\ \text{hours} + 2\ \text{hours} = -3\ \text{hours} = 9:00 PM\ \text{yesterday}
# \]
#
# ---
#
# ### Step 11: Verify if this makes sense
#
# Check if two hours ago at 7:00 PM yesterday satisfies the condition.
#
# - How long after 1:00 PM (yesterday) is 7:00 PM yesterday?
#
# \[
# 7:00 PM = 19:00, 1:00 PM = 13:00
# \]
#
# \[
# 19:00 - 13:00 = 6\ \text{hours}
# \]
#
# - How long before 1:00 AM yesterday is 7:00 PM yesterday?
#
# Since 7:00 PM is after 1:00 AM same day, the "before 1:00 AM yesterday" is actually **backwards in time.**
#
# If we consider 1:00 AM yesterday as earlier in time, and 7:00 PM yesterday as later, then the difference "before 1:00 AM yesterday" is negative (i.e., it is after 1:00 AM yesterday).
#
# This means the interpretation might require us to think about the problem differently.
#
# ---
#
# ### Alternative Interpretation:
#
# Given the phrase
# > "Two hours ago, it was as long after 1 o’clock in the afternoon as it was before 1 o’clock in the morning yesterday."
#
# Meaning: The time two hours ago is equidistant between 1:00 PM **today** and 1:00 AM **yesterday**.
#
# So:
#
# - 1:00 AM yesterday → \( t = -23 \) hours (relative to midnight today)
# - 1:00 PM today → \( t = 13 \) hours
#
# Time two hours ago (\( t_0 \)) is at midpoint of these two times:
#
# \[
# t_0 = \frac{13 + (-23)}{2} = \frac{-10}{2} = -5\ \text{hours}
# \]
#
# This is 5 hours before midnight today = 7:00 PM yesterday.
#
# Hence,
#
# Current time:
#
# \[
# T = t_0 + 2 = -5 + 2 = -3 \text{ hours} \implies 9:00\ \text{PM yesterday}
# \]
#
# ---
#
# ### Step 12: Final answer
#
# **The current time is 9:00 PM yesterday."
#
# ---
#
# ### Step 13: Confirm if such an answer makes sense theoretically
#
# Having the current time on yesterday is unusual in the context of a clock problem and a normal day, so let's convert this to the standard 12-hour clock format:
#
# - 9:00 PM yesterday = 21:00 (previous day).
#
# If the question does not restrict current time to "today," then this is the only solution.
#
# ---
#
# ### Conclusion:
#
# The current time is **9:00 PM yesterday**.
#
# If we need a current time in today (same day time), this is impossible unless we allow crossing day boundaries.
#
# ---
#
# # **Answer:**
#
# **The current time is 9:00 PM (21:00) the previous day (yesterday).**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step.
#
# ---
#
# ### Problem restatement:
# > Two hours ago, the time was *as long after* 1:00 PM as it was *before* 1:00 AM **yesterday**.
#
# We want to find **the current time**.
#
# ---
#
# ### Step 1: Define variables and interpret the problem
#
# - Let the current time be \( T \) (in hours and minutes, or decimal hours).
# - Two hours ago, the time was \( T - 2 \).
#
# The problem refers to two reference points on the clock:
# - 1:00 PM (13:00) **today**.
# - 1:00 AM (1:00) **yesterday**.
#
# "Two hours ago, it was as long after 1:00 PM as it was before 1:00 AM yesterday."
#
# ---
#
# ### Step 2: Understand "as long after" and "as long before"
#
# - "As long after 1:00 PM" means the difference between \( T-2 \) and 13:00, specifically:
#   \[
#   \text{time after 1:00 PM} = (T - 2) - 13:00
#   \]
#
# - "As long before 1:00 AM yesterday" means the difference between 1:00 AM **yesterday** and \( T-2 \), specifically:
#   \[
#   \text{time before 1:00 AM yesterday} = 1:00\ \text{AM yesterday} - (T - 2)
#   \]
#
# Since \( T - 2 \) is after 1:00 PM today, the "before 1:00 AM yesterday" time interval refers to the **duration from \( T-2 \) backwards in time to 1:00 AM of the previous day**.
#
# ---
#
# ### Step 3: Set a timeline reference
#
# To compare times consistently, it's best to convert all times into a continuous time measurement, e.g., hours elapsed since a reference point.
#
# Let’s use **midnight at the start of today** (00:00 AM today) as reference:
#
# - 1:00 PM today is: \( 13 \) hours after midnight.
# - 1:00 AM yesterday is: \( 1 \) hour after midnight **yesterday**.
#
# Since yesterday is 24 hours before today, 1:00 AM yesterday is \( 1 - 24 = -23 \) hours relative to midnight today.
#
# ---
#
# ### Step 4: Express everything as hours relative to midnight today
#
# Let current time \( T \) be hours after midnight today. So \( T \) is between 0 (midnight) and 24 (next midnight).
#
# Two hours ago is \( T - 2 \).
#
# We write the condition:
#
# \[
# \text{(after 1:00 PM)} = \text{(before 1:00 AM yesterday)}
# \]
#
# In hours,
#
# \[
# (T - 2) - 13 = (-23) - (T - 2)
# \]
#
# ---
#
# ### Step 5: Solve the equation
#
# \[
# (T - 2) - 13 = -23 - (T - 2)
# \]
#
# Simplify left side:
#
# \[
# T - 15 = -23 - T + 2
# \]
#
# \[
# T - 15 = -21 - T
# \]
#
# Bring all terms to one side:
#
# \[
# T + T = -21 + 15
# \]
#
# \[
# 2T = -6
# \]
#
# \[
# T = -3
# \]
#
# A negative time \( T = -3 \) means 3 hours **before** midnight today, i.e., 21:00 (9:00 PM) the day before. The negative outcome suggests we must reconsider what \( T \) means and whether \( T \) is on the same day or not.
#
# ---
#
# ### Step 6: Check the time domain assumptions
#
# - Current time \( T \) cannot be negative.
# - This means the answer is **before midnight today** or on the previous day.
# - Since \( T = -3 \) hours relative to midnight today, it corresponds to 9:00 PM yesterday.
#
# ---
#
# ### Step 7: Interpret \( T = -3 \) (9:00 PM yesterday)
#
# - Current time \( T = -3 \) = 9:00 PM yesterday
# - Two hours ago \( T - 2 = -5 \) = 7:00 PM yesterday
#
# Check if condition holds:
#
# - After 1:00 PM (13:00) today:
#
#   \( (T - 2) - 13 = -5 - 13 = -18 \) hours
#
#   Negative means that \( T-2 \) is **before** 1:00 PM today, so no.
#
# Try interpreting "after 1:00 PM" and "before 1:00 AM" differently.
#
# ---
#
# ### Step 8: Consider the problem from a 12-hour clock perspective
#
# Maybe the problem is about the **clock time only**, not absolute times.
#
# ---
#
# ### Step 9: Interpret the statement differently
#
# "Two hours ago, it was as long after 1 o’clock in the afternoon as it was before 1 o’clock in the morning yesterday."
#
# Translate literally:
#
# - Let \( t_0 \) = time two hours ago.
#
# - Then,
#
# \[
# t_0 - 13:00 = 1:00\ \text{AM yesterday} - t_0
# \]
#
# But 1:00 AM yesterday is 24 hours **before** 1:00 AM today, so the difference \( 1:00 AM yesterday - t_0 \) expresses a time interval.
#
# If:
#
# \[
# (t_0 - 13:00) = (1:00 AM yesterday - t_0)
# \]
#
# then adding \( t_0 + t_0 \) to both sides:
#
# \[
# 2t_0 = 13:00 + 1:00 AM yesterday
# \]
#
# ---
#
# ### Step 10: Representing times as minutes from a base point
#
# Represent both times as minutes from a reference:
#
# - Let the reference be midnight today.
#
# - \( t_0 \) is some time between 0 and 24 hours.
#
# 1:00 AM yesterday is -23 hours from midnight today, or
#
# \[
# -23 \times 60 = -1380 \text{ minutes}
# \]
#
# 13:00 today is
#
# \[
# 13 \times 60 = 780 \text{ minutes}
# \]
#
# The equation:
#
# \[
# 2t_0 = 780 + (-1380) = -600 \text{ minutes}
# \]
#
# \[
# t_0 = -300 \text{ minutes} = -5 \text{ hours}
# \]
#
# So two hours ago was 5 hours before midnight today, which is 7:00 PM yesterday.
#
# Thus the current time \( T = t_0 + 2 \) is
#
# \[
# -5\ \text{hours} + 2\ \text{hours} = -3\ \text{hours} = 9:00 PM\ \text{yesterday}
# \]
#
# ---
#
# ### Step 11: Verify if this makes sense
#
# Check if two hours ago at 7:00 PM yesterday satisfies the condition.
#
# - How long after 1:00 PM (yesterday) is 7:00 PM yesterday?
#
# \[
# 7:00 PM = 19:00, 1:00 PM = 13:00
# \]
#
# \[
# 19:00 - 13:00 = 6\ \text{hours}
# \]
#
# - How long before 1:00 AM yesterday is 7:00 PM yesterday?
#
# Since 7:00 PM is after 1:00 AM same day, the "before 1:00 AM yesterday" is actually **backwards in time.**
#
# If we consider 1:00 AM yesterday as earlier in time, and 7:00 PM yesterday as later, then the difference "before 1:00 AM yesterday" is negative (i.e., it is after 1:00 AM yesterday).
#
# This means the interpretation might require us to think about the problem differently.
#
# ---
#
# ### Alternative Interpretation:
#
# Given the phrase
# > "Two hours ago, it was as long after 1 o’clock in the afternoon as it was before 1 o’clock in the morning yesterday."
#
# Meaning: The time two hours ago is equidistant between 1:00 PM **today** and 1:00 AM **yesterday**.
#
# So:
#
# - 1:00 AM yesterday → \( t = -23 \) hours (relative to midnight today)
# - 1:00 PM today → \( t = 13 \) hours
#
# Time two hours ago (\( t_0 \)) is at midpoint of these two times:
#
# \[
# t_0 = \frac{13 + (-23)}{2} = \frac{-10}{2} = -5\ \text{hours}
# \]
#
# This is 5 hours before midnight today = 7:00 PM yesterday.
#
# Hence,
#
# Current time:
#
# \[
# T = t_0 + 2 = -5 + 2 = -3 \text{ hours} \implies 9:00\ \text{PM yesterday}
# \]
#
# ---
#
# ### Step 12: Final answer
#
# **The current time is 9:00 PM yesterday."
#
# ---
#
# ### Step 13: Confirm if such an answer makes sense theoretically
#
# Having the current time on yesterday is unusual in the context of a clock problem and a normal day, so let's convert this to the standard 12-hour clock format:
#
# - 9:00 PM yesterday = 21:00 (previous day).
#
# If the question does not restrict current time to "today," then this is the only solution.
#
# ---
#
# ### Conclusion:
#
# The current time is **9:00 PM yesterday**.
#
# If we need a current time in today (same day time), this is impossible unless we allow crossing day boundaries.
#
# ---
#
# # **Answer:**
#
# **The current time is 9:00 PM (21:00) the previous day (yesterday).**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "You are an expert business consultant. Please propose a business idea that is innovative, profitable, and has a clear target market for Agentic AI. Respond only with the business idea."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

display(Markdown(f"**Business Idea:** {business_idea}"))

# And repeat! In the next message, include the business idea within the message
# Out:
# **Business Idea:** Agentic AI-Powered Virtual Personal Assistant for Small and Medium Enterprises (SMEs): Develop an AI-driven virtual assistant platform that autonomously manages administrative, sales outreach, customer support, and workflow optimization tasks tailored specifically for SMEs. Leveraging agentic AI’s ability to independently plan, learn, and execute multi-step processes, the platform reduces the need for extensive human oversight, significantly cutting operational costs and increasing productivity. Target market: SMEs across industries seeking affordable, scalable automation solutions to streamline operations and accelerate growth.

# %%
messages = [{"role": "user", "content": f"You are an expert business consultant. Please propose a pain point for the business idea: {business_idea}. Respond only with the pain point."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_point = response.choices[0].message.content
display(Markdown(f"**Pain Point:** {pain_point}"))
# Out:
# **Pain Point:** SMEs struggle with limited resources and expertise to efficiently manage diverse operational tasks, leading to high labor costs, operational bottlenecks, and missed growth opportunities due to the lack of affordable, intelligent automation solutions that can autonomously handle complex, multi-step processes without constant human oversight.

# %%
messages = [{"role": "user", "content": f"You are an expert business consultant in the Agentic AI industry. Please propose an Agentic AI solution to the pain point: {pain_point} fo the following business idea {business_idea}. Respond only with the solution."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content
display(Markdown(f"**Solution:** {solution}"))
# Out:
# **Solution:** Solution:
#
# Develop an Agentic AI-Powered Virtual Personal Assistant (VPA) platform explicitly designed for SMEs, featuring the following capabilities:
#
# 1. **Autonomous Multi-Domain Task Management:** The VPA autonomously handles diverse operational tasks—including scheduling, invoicing, inventory tracking, sales outreach, and customer support—by independently planning and executing complex, multi-step workflows tailored to each SME’s specific processes and industry requirements.
#
# 2. **Adaptive Learning and Customization:** Utilizing continuous learning algorithms, the VPA adapts to evolving business workflows and customer interactions, improving efficiency and relevance without the need for constant human input or reprogramming.
#
# 3. **Integrated Communication and CRM Automation:** The assistant connects seamlessly with common communication channels, CRM systems, and ERP software to coordinate outreach campaigns, follow-ups, order processing, and customer inquiries, automating repetitive administrative work and enabling personalized engagement at scale.
#
# 4. **Workflow Optimization and Bottleneck Identification:** By monitoring operational data and workflow execution, the VPA proactively identifies process inefficiencies and suggests or implements optimizations, helping SMEs eliminate bottlenecks and reallocating resources effectively.
#
# 5. **User-Friendly Interface with Minimal Setup:** SMEs can easily onboard and configure the platform with minimal technical expertise, leveraging pre-built industry-specific templates and AI-driven recommendations to accelerate adoption and immediate value realization.
#
# 6. **Affordable, Scalable SaaS Model:** Offered as a subscription-based cloud service with tiered plans, the solution ensures accessibility for SMEs of varying sizes and growth stages, making sophisticated automation economically viable without significant upfront investment.
#
# This agentic AI VPA empowers SMEs to reduce reliance on large operational teams, lower labor costs, and unlock growth potential by autonomously managing complex tasks end-to-end, allowing business owners and employees to focus on strategic initiatives and customer relationship expansion.
